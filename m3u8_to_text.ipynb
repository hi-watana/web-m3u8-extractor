# %%
# !pip install -U faster-whisper ffmpeg-python
# !apt-get install -y ffmpeg
# Out:
# Collecting faster-whisper
#   Downloading faster_whisper-1.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting ctranslate2<5,>=4.0 (from faster-whisper)
#   Downloading ctranslate2-4.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (0.34.4)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (0.21.4)
# Collecting onnxruntime<2,>=1.14 (from faster-whisper)
#   Downloading onnxruntime-1.22.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Collecting av>=11 (from faster-whisper)
#   Downloading av-15.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (4.67.1)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (2.0.2)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (1.1.8)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster-whisper)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.13.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Downloading faster_whisper-1.2.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.8 MB/s eta 0:00:00
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading av-15.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 24.7 MB/s eta 0:00:00
# Downloading ctranslate2-4.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.8/38.8 MB 20.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 121.7 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.5 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, ffmpeg-python, ctranslate2, av, coloredlogs, onnxruntime, faster-whisper
# Successfully installed av-15.1.0 coloredlogs-15.0.1 ctranslate2-4.6.0 faster-whisper-1.2.0 ffmpeg-python-0.2.0 humanfriendly-10.0 onnxruntime-1.22.1
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
m3u8_url = 'https://fast.wistia.com/embed/medias/gukws7niwp.m3u8'
#m3u8_url = 'https://fast.wistia.com/embed/medias/sttq0tqmic.m3u8'

# %%
m3u8_url_tmp = input('Enter M3U8 URL: ').strip()
m3u8_url = m3u8_url_tmp if m3u8_url_tmp else m3u8_url
# Out:
# Enter M3U8 URL: https://embed-ssl.wistia.com/deliveries/b88abc1311b378a1e438a9bfeb8de2b28cb9a578.m3u8

# %%
m3u8_url
# Out:
# 'https://embed-ssl.wistia.com/deliveries/b88abc1311b378a1e438a9bfeb8de2b28cb9a578.m3u8'

# %%
import ffmpeg

def extract_audio_from_m3u8(m3u8_url, output_path='output.mp3'):
    stream = ffmpeg.input(m3u8_url, hwaccel="cuda", hwaccel_device="0")
    stream = ffmpeg.output(stream, output_path, acodec="libmp3lame", vn=None, vcodec='h264_nvenc', preset='ultrafast')
    ffmpeg.run(stream, overwrite_output=True)

# %%
from faster_whisper import WhisperModel

def transcribe_audio(audio_path, model_size="small"):
    model = WhisperModel(model_size, device="auto", compute_type="int8")
    segments, info = model.transcribe(audio_path, language="ja")
    segment_list = [] # Use a list to collect segments
    for segment in segments:
        print(segment.text)
        segment_list.append(segment.text) # Append segment text to the list
    return " ".join(segment_list) # Join the list elements at the end

# %%
def m3u8_to_transcript(m3u8_url, audio_path='output.mp3', model_size="small"):
    extract_audio_from_m3u8(m3u8_url, audio_path)
    transcript = transcribe_audio(audio_path, model_size)
    return transcript

# %%
url = m3u8_url
text = m3u8_to_transcript(url, model_size='medium')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# vocabulary.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.bin:   0%|          | 0.00/1.53G [00:00<?, ?B/s]
# 世界は産業革命に匹敵する変革の時を迎えています 世界最大の資産運用会社ブラックロック
# ai の進歩は我々を最も驚かせた世界最大級の投資銀行ゴールドマンサックス ai の次の波はロボットだ
# n ビディア ceo ジェンスンファン これまでの人類の歴史上最大の製品になる可能性がある
# テスラ ceo イーロンマスク 今ご紹介した言葉はいずれも ai ブームの次のトレンドについて語られたものです
# 資産運用会社ブラックロックのアナリストは今の ai ブームは産業革命に匹敵する変革であると語り ai の次に高い成長が狙える分野はロボットだと
# 語りました ゴールドマンサックスのアナリストは ai の急速な進化によりロボット市場の成長率の予測を情報修正
# 以前の予測である60億ドルから6倍以上の380億ドルに変更しました ai の進歩は我々を最も驚かせたとアナリストは語っています
# 現在の生成 ai の波を経緯する nvidia の ceo ジェンスファンはロボットを刺しながらこれが ai の次の波だと発言
# ai が搭載された自立マシンやロボットが普及する未来の可能性について語りました イーロンマスク氏が率いるテスラは二足歩行する人型ロボット
# オプティマスの開発を発表 テスラボットとも呼ばれるこの人型ロボットは掃除や洗濯料理の補助など日常的な家事の
# サポート高齢者や障害者の生活支援子供の教育支援など幅広い活用が期待されています イーロンマスク氏はテスラにとっていずれ自動車事業よりも重要になる可能性がある
# 2025年に自社工場で1000台以上を稼働させる これまでの人類の歴史上最大の製品になる可能性があると語っています
# その中にはこのロボットがテスラの自家総額を40倍以上に押し上げるといった驚きの 主張もあります
# ここまでの話を聞いたあなたはロボットなんて実現しない 実現したとしても遠い未来だと思われるかもしれません
# 確かに人型ロボットが私たちの生活に普及するのは遥か先の未来 もしくは全く実現しない可能性もあります
# ですがAIが搭載された機械は実はもうすでに私たちの生活に浸透しつつあります それはAIスマホです
# 現在生成AIが搭載されたスマートフォンAIスマホが世の中に普及しつつあります 例えばアップルは独自の生成AIアップルインテリジェンスを搭載したAIスマホを発売
# 中でも今年2月に発売されたiphone6 teはアップルインテリジェンスの活用により最強の AIスマホと呼ばれています
# 人気シリーズギャラクシーを発売するサムソンも生成AIを搭載したスマホを開発 まるで秘書がスマホの中にいるようだや仕事を任せられるといったほどの
# 画期的な性能を誇っていると言われています 生成AIジェミニを提供するグーグルも生成AIを搭載したグーグルピクセルを発売
# AIスマホを開発するのは既存のスマホメーカーだけではありません チャットGPTを開発したオープンAIもAI界のiPhoneを目指してAIスマホの開発を発表
# この計画にはiPhone、iMac、Apple Watchなどのアップルの主要な製品のデザインを多数手掛けた 元アップルの伝説的なデザイナージョナサン・アイブが参画しています
# 彼は2019年にアップルを退社しましたがそれまでアップルの最高デザイン責任者を務めており 初代iPhoneも彼の作品です
# オープンAIとジョナサン・アイブ氏が手掛けるAI界のiPhone どんなスマホになるのかまだ詳しいことは明かされていませんが
# スマホにAIが搭載されることは間違いないでしょう AIスマホの登場は私たちの生活を大きく変えるイノベーションになるかもしれません
# アップルが初代iPhoneを発表した2007年1月9日 その日アップルのCEOスティーブ・ジョブズは本日アップルが電話を再発明すると高らかに宣言し
# 初代iPhoneを発表しました 宣言通りiPhoneは電話を再発明したと言っても過言ではありません
# それまで日本では柄系と呼ばれるモバイル端末が主流でしたが iPhoneをはじめスマートフォンが使われるようになりました
# 2010年の携帯電話所有者のスマホの比率は4.4% それが10年で88.9%まで上昇しました
# この期間アップルの株価は1,028%上昇 これは100万円投資していれば資産を1,128万円までに増やすことができていたということです
# そしてAIスマホの普及が期待される2025年 AIスマホを提供し電話を再発明する企業の中から高い株価成長を果たすものが出てくるかもしれません
# さらに今回の電話の再発明はアップルの時よりも高いリターンが狙える可能性があります
# なぜならアップルが初代iPhoneを発売した2007年と現在では世界人口が圧倒的に違うからです
# 2007年から2025年現在までの間で世界人口は14.6億人も増加したと言われています
# それだけ多くの人がAIスマホを持つようになれば当然AIスマホ市場を支配する企業はアップルよりも高い株価成長を果たす可能性があります
# AIスマホ市場を支配する端末をスマホの先書きになったiPhoneに掛け合わしGPTフォンと私たちは呼んでいます
# GPTフォンを開発しAIスマホ市場を支配する企業にいち早く投資をすることができれば
# 初代iPhoneを発売した時のアップル以上に高いリターンを狙うことができるかもしれません
# GPTフォンを発売しアップルの次に電話を再発明するのはどの企業になるのでしょうか
# 元アップルの伝説的なデザイナーと手を組んだオープンAIでしょうか
# スマホ市場の勝者アップルが今回も電話を再発明することになるのでしょうか
# それとも全く別の企業が革命を起こすことになるのでしょうか
# 実はもうすでにスマホを超えたと称されるAIデバイスを開発した企業が存在します
# この動画ではその企業についても紹介しています
# さらにどの企業がGPTフォンを発売することになったとしても
# 利益が狙える名柄も名前まで明かして紹介しているので
# この動画を見るだけでNVIDIA CEO Jensenファンが語るAIの次の波に乗って
# 高いリターンを狙うことができます
# このページにたどり着いた今動画を見てぜひ投資を検討してみてください
# チャプター1 未来のスマホGPTフォンにはアプリがない
# いずれスマートフォンのアプリは消える
# なぜならAIがアプリにとって変わるからだ
# そう主張するのは世界的な通信事業者ドイツテレコム社のCEOです
# ドイツテレコム社が発売したティーフォンにはアプリはありません
# AIがアプリの役割を果たします
# ユーザーはAIにしたいことを伝えるだけでいいのです
# 旅行に行きたい時
# 航空券を予約したいと端末に伝えるだけで
# ホーム画面に候補となるフライトのリストが表示されます
# あとは好きなモバイル決済システムで即座に支払いまで完了できます
# 他のアプリやサービスに切り替える必要は一切ありません
# ティーフォンを開発したドイツテレコム社のCEOは次のように語っています
# 今のアプリシステムはユーザーが考えなければならないことが多い
# しかし今後はAIにしたいことを伝えるだけで
# AIが必要なフローを組み立ててくれる
# さらにアプリのないスマホを開発したのは彼だけではありません
# 他にもアプリが存在しないモバイル端末を発売したスタートアップ企業が存在します
# あなたは毎年1月にラスベガスで開催される
# カスタマーエレクトロニクスショー通称SESをご存知でしょうか?
# このイベントには毎年世界中から数千社以上のテクノロジー企業が集まり
# 最先端のデジタル製品が披露されます
# 昨年開催されたSES2024でも世界中から4千を超える企業が出展
# 13万人近くの参加者が訪れました
# 空飛ぶ車や中身が透けて見える透明なテレビなど
# 革新的な商品が会場に並ぶ中
# スマホを超えると称されるモバイル端末が紹介されました
# そのモバイル端末はラビット社が開発したラビットR1です
# 日本のメディアもニュースに取り上げているので
# あなたもご存知あるかもしれません
# スマホを超えると言われていますが
# その見た目はスマホとは全く異なるものです
# ご覧の通りこのモバイル端末にはスクロールホイールがついているだけです
# 画面はタッチスクリーンであるものの
# スマホの半分程度のサイズしかありませんし
# アプリも存在しません
# そんなモバイル端末をどうやって操作するのか
# 疑問に思われたかもしれません
# ラビットR1は音声で操作が可能です
# 何かのタスクをこなすためには適切なアプリを探し出し
# 画面を何度もタップする必要はありません
# ユーザーはラビットR1の側面についたボタンを押しながら
# やりたいことを友達にお願いするように伝えるだけでいいのです
# ラビットR1は数秒でユーザーのリクエストを解析し
# 画面にうんちんなどの詳細を示すカードを表示
# 廃車を依頼します
# ラビットR1ができることは滝にわたります
# レストランの予約や航空券の予約
# Spotifyのプレイリストへの曲の追加
# 様々なことがアプリなしで音声操作が可能です
# iPhoneのSiriやGoogleアシスタントとは異なり
# ラビットR1には高性能なAIが搭載されており
# ユーザーの行動を学習し
# ユーザーが望む行動を正確に実行することができます
# それにより従来のスマートフォンには
# 不可能な音声操作が可能となっているということです
# ラビットR1の販売価格は199ドル
# 約2万9000円で販売が始まりましたが
# たった1日で初回販売台数の1万台は売り切れとなりました
# ラビットR1を開発したラビット社は
# 発売日に500台の販売を予測していましたが
# それを大きく上回る販売台数です
# すぐに販売台数を1万台増加しましたが
# それでも24時間後には売り切れ
# 節での発表からわずか8日間で
# 4万台も販売されたといいます
# チャットGPTもリリースからわずか5日で
# ユーザー数が100万人を突破するという
# 異行を成し遂げましたが
# チャットGPTを彷彿させるリリースを飾りました
# もしかしたらラビット社が開発した
# ラビットR1がAppleの次に電話を再発明する
# GPTフォンになるかもしれません
# どの企業のモバイル端末がGPTフォンになるにしても
# 未来のスマホにはアプリは必要なく
# スマホに搭載されたAIが
# アプリの代わりを果たすことになるのでしょう
# 私たちはもう画面をスクロールして
# アプリを探す必要はありません
# スマホに搭載されたAIに
# 自分がやりたいことを伝えるだけでいいのです
# ニューヨークに拠点を置く経済メディア
# ビジネスインサイダーは
# AIがスマートフォンに浸透するにつれ
# アプリ自体の終焉が見えてくるかもしれないと報道
# 記事の中ではAIについて様々な議論があるが
# 一つはっきりしていることがある
# それはAIがスマホに搭載されることだと論じています
# 世界的なメディアフォーブスも
# 人工知能はスマートフォンアプリの
# 終焉をもたらすのかと論じています
# 他にもフォーブスはデバイス上の生成AIが
# スマートフォンとPCの真の価値を
# 引き出すという記事も出しています
# GPTフォンがどのような端末で
# どの企業が発売することになるのか分かりません
# しかしモバイル端末にAIが搭載されていくことは
# ほぼ間違いないのでしょう
# IT分野専門のリターチ機関MM総研によると
# 昨年度のAIスマホの出荷台数は
# 前年度比約3倍の1149万台になったと言われています
# さらに4年後の2028年度には2317万台になり
# 全体の90%近くを占めるという予測を出しています
# それだけAIスマホが世の中に
# 普及していくと予測されているということです
# 次のチャプターでは
# どの企業が電話を再発明するGPTフォンを
# 開発することになったとしても
# AIスマホの普及で利益が狙える投資先を
# 名柄名まで明かして紹介していきます
# チャプター2
# AIスマホが普及したときに
# 高いリターンが狙える投資先
# スマホを超えると称される
# AIモバイル端末ラビットR1を
# 開発した企業ラビット社
# 実はラビット社はスタートアップ企業で
# 私たち個人投資家が投資することはできません
# しかし仮に投資することができたとしても
# ラビットR1に投資することはお勧めしません
# なぜならスマホを超えると称された
# AIモバイル端末はラビットR1だけではないからです
# ラビットR1はセス2024に展示されていたことを
# お話ししましたが
# そのときスマホを超えると称される
# モバイル端末がもう一つ発表されていました
# それはAppleの元幹部が設立した
# スタートアップ企業Humaneが開発した
# このモバイル端末には
# アプリはもちろん画面すらありません
# ラビットR1と同じく
# このAIピンも主に音声で操作します
# AIピンには小さなプロジェクターが
# 搭載されており
# ユーザーの手のひらに受信したメッセージや
# 検索した情報などを表示できます
# 開発者がAppleの元幹部ということもあり
# 注目を集めてスマホを超えると
# 称されることもありましたが
# 今年の2月にサービスは終了
# AIピンを開発したHumaneは
# 米国の大手パソコンメーカー
# Hulet Packard社による
# 買収が発表されています
# リリース当初は注目を集めたものの
# 高額すぎる料金体系と
# 製品の不具合で
# 売り上げを上回るほど
# 返品があったと報道されていました
# やはり世の中を革新する商品を
# 普及させることは難しいのでしょう
# リリースで大成功を収めた
# ラビットR1も今後どうなるか分かりません
# Appleの次に電話を再発明する
# GPTフォンを特定し
# 開発する企業に投資することは
# 難しいのでしょう
# ですがどの企業がGPTフォンを
# 開発しても利益が狙える
# 投資先があります
# その投資先を知るヒントは
# ラビットR1とAIピン
# この2つのモバイル端末の
# 共通点にあります
# この2社のモバイル端末には
# スマホを超えると称されたこと以外に
# もう1つ別の共通点があります
# それはどちらのモバイル端末にも
# チャットGPTのAIが
# 搭載されていることです
# どちらの企業も
# ゼロからAIを開発するのではなく
# チャットGPTのAIをベースに
# 独自の機能を加えて
# 開発したAIを使用しています
# チャットGPTのAIをベースに
# 独自のAIを開発しているのは
# この2社だけではありません
# AppleもiPhoneにAIを搭載しましたが
# 搭載されたAIは
# Appleが全て独自開発したものではありません
# AppleはOpenAIと提携を組み
# チャットGPTの機能をiPhoneに
# 一部実装しています
# 独自開発を好むAppleですが
# AIは自社で開発するよりも
# OpenAIと提携契約を
# 結んだ方が良いと判断したのかもしれません
# それほどまでにOpenAIが開発した
# チャットGPTは優れているということです
# 当然OpenAIも非常上企業なので
# 投資することはできませんが
# OpenAIの最大の出資者である
# Microsoftに投資をすることで
# 間接的にOpenAIに投資することができます
# OpenAIとAppleの伝説的なデザイナーが開発する
# AI界のiPhone
# Rabbit社が開発したRabbit R1
# Appleが開発するAI搭載のiPhone
# どのモバイル端末が
# 電話を再発明するGPTフォンになるのか
# 予測する必要はありません
# Microsoftに投資していれば
# どのモバイル端末がGPTフォンになったとしても
# 高いリターンを狙うことができます
# Microsoftに投資して
# OpenAIに間接的に投資するなんて
# 当たり前の話を聞きたかったわけではない
# Cloud3やChemnyなど
# チャットGPTを超えると言われるほど
# 優れた性能を持った生成AIが登場している
# もし他の企業が開発した生成AIが
# 派遣を取ったらどうするんだ
# そのモバイル端末にチャットGPTが
# 搭載されている保障はないんじゃないか
# ここまでの話を聞いたあなたは
# このように思われたかもしれません
# ご安心ください
# 未来のスマートフォンが普及した時に
# 最もベストな投資先は
# Microsoftではありません
# 最もベストな投資先は
# 未来のスマートフォンに
# どんな生成AIが搭載されるのかについて
# 関係なく高いリターン
# それもGPTフォンを開発した企業や
# OpenAIに出資している
# Microsoftよりも高いリターンを狙えます
# その投資先について知りたい方は
# このまま動画をご覧ください
# チャプター3
# 未来のスマートフォンが普及した時に
# より高いリターンを狙う方法
# スマホの先書きになったiPhone
# スマホが普及した2010年代
# Appleの株価は10年間で
# 1028%上昇したことを紹介しましたが
# この期間でApple株よりも
# 高い株価成長を遂げた銘柄があります
# それはAppleに通信用
# 半導体チップを提供した
# 半導体メーカーのブロードコムでした
# Appleの株価が1028%の
# 株価成長を果たした10年間で
# ブロードコムの株価は1655%上昇
# これはApple株の1.6倍高いリターンです
# 初代iPhoneが発売された時
# 投資家が投資すべき企業は
# Appleではありませんでした
# 投資家はブロードコムに
# 投資しておくべきだったということです
# これは初代iPhoneの時だけではありません
# AppleがiPhone3Gを発売した
# 2008年7月11日
# iPhone3Gに搭載される
# 半導体を製造していた
# シーラスロジック社は
# 発売当日の2008年7月11日から
# 2010年7月12日までの2年間で
# 268%もの株価成長を達成
# AppleがiPhone3Gを発売した
# 2ヶ月後にリーマンショックが発生し
# S&P500は約1年で
# 50%近く下落したのにも関わらず
# 268%もの株価成長を果たしました
# 同期間のAppleの株価成長率は49%
# 半導体メーカーのシーラスロジック社の株価の方が
# 5.4倍も高い株価成長を実現していたということです
# AppleがiPhone5を発売した
# 2012年9月21日
# iPhone5に搭載される半導体を製造する
# NXPセミコンダクターズは
# 発売当日の2012年9月21日から
# 2015年5月29日までの
# 約2年半の間で
# 336%もの株価成長を達成
# 同期間のAppleの株価成長率は38%
# 半導体メーカーのNXPセミコンダクターズの株価の方が
# 8.8倍も高い株価成長を実現していたということです
# 電話を再発明したApple
# そんなAppleが新型iPhoneを発売するとき
# Apple株に投資するのではなく
# 新型iPhoneに内蔵される
# 半導体を提供する企業に投資をしておけば
# 高いリターンを得ることができていたということです
# 2025年現在
# AIが搭載されたスマートフォンが
# 普及しようとしていますが
# どのモバイル端末がGPTフォンになるのかも
# どの生成AIがGPTフォンに搭載されるのかも
# 予測する必要はありません
# なぜならGPTフォンに内蔵される
# 半導体チップを製造する企業に投資をすれば
# GPTフォンを提供する企業の株よりも
# 高いリターンを狙うことができるからです
# ファイナルチャプター
# AIスマホに内蔵される半導体チップを製造する企業
# AIをスマートフォンに搭載する
# 簡単そうに聞こえますが
# これは難しいことなのです
# 生成AIといえばチャットGPTですが
# チャットGPTが稼働するのに
# どれぐらいの電力を消費するかご存知でしょうか
# 毎日世界中からチャットGPTの元に
# 2億件のチャットが送られていると言われています
# その2億件のチャットを処理するのに
# 必要な消費電力はなんと50万キロワット
# 米国の平均的な家庭では
# わずか29キロワットしか使用していません
# つまりチャットGPTは平均的な家庭の
# 1万7000倍以上の電力を
# 消費しているということです
# 私たちは自分のパソコンやスマホで
# チャットGPTを使うことができますが
# チャットGPTのAIはパソコンやスマホに
# 搭載されているわけではありません
# チャットGPTのAIはデータセンターに存在しており
# データセンターに供給される電力で
# チャットGPTは稼働しています
# 今まで私たちはインターネットを介して
# データセンターで稼働するAIを使っているので
# 消費電力を気にする必要はありませんでしたが
# 生成AIをスマートフォンに
# 搭載するとなると話は別です
# 平均的な家庭の1万7000倍以上の電力を
# 消費するチャットGPTの電力を
# スマートフォンに内蔵されたバッテリーで
# まかなうことは不可能に近いからです
# 生成AIが1枚の画像を生成するのに
# 必要な電力はスマホを充電するのと
# 同等の電力が必要だと言われています
# 1枚の画像を生成するごとに
# 充電が切れるスマホなんて
# とても使えないですよね
# 生成AIの膨大な消費電力は
# AIスマホにとって大きな課題ですが
# この課題を解決する
# 特殊な半導体が存在します
# 従来の半導体はシリコンから作られますが
# この半導体は違います
# 我々がGPTシリコンと呼ぶ
# 特別な素材から作られます
# GPTシリコンで作られた半導体は
# 電気効率が良く
# 消費電力を90%近く削減することができます
# なので膨大な電力を消費するAIを
# 端末に搭載する際に
# GPTシリコンから作られた
# 半導体が利用されます
# AI搭載のスマートフォンに
# 必要なGPTシリコン
# その市場は2035年に
# 2022年比で31.1倍になると
# 言われています
# NVIDIAが含まれる
# 従来のシリコン半導体市場の
# 成長予測は同じ期間で3.2倍
# つまりGPTシリコン市場は
# 従来のシリコン半導体市場の
# 約9.8倍の成長が
# 予測されているということです
# そんな高成長が期待できる
# GPTシリコン市場には
# 圧倒的な勝者企業が存在します
# その企業こそが未来のスマートフォンに
# どんな生成AIが搭載されるのか関係なく
# 高いリターン
# それも未来のスマートフォンが
# 普及した未来で
# GPTフォンを開発した企業や
# オープンAIに出資している
# マイクロソフトよりも
# 高いリターンを狙うことができる
# 投資先です
# この企業はGPTシリコン市場で
# シェア率No.1
# シェア率No.2の企業よりも
# 2倍近い市場占有率を誇る
# 圧倒的な地位にいます
# それだけではありません
# スマホを超えると称される
# モバイル端末のラビットR1
# AIピン
# GoogleのAIスマホ
# 生成AIが搭載された
# iPhoneの最新モデル
# iPhone6TEにも
# この企業の半導体が搭載されています
# 未来のスマートフォン
# GPTフォンがどの企業から発売されるのか
# 予測する必要はありません
# なぜならスマホにAIを搭載するには
# 電気効率が良い
# GPTシリコンを活用することになりますが
# その市場で圧倒的な勝者である
# この企業の半導体が使われる
# 可能性が高いからです
# 半導体企業といえば
# NVIDIAが投資家からの注目を集めていますが
# 3つの理由から
# NVIDIAよりも投資すべき半導体名柄だと
# 私たちWISE Ratings Japanは考えています
# まず1つ目の理由は
# NVIDIAのAI半導体は
# 端末上に搭載するには
# 電気効率の問題で適していないからです
# チャットGPTは平均的な家庭の
# 17000倍以上の電力を消費している
# というお話をしましたが
# チャットGPTに使われている半導体は
# NVIDIA製のものです
# 平均的な家庭の17000倍以上の電力を
# 消費するチャットGPTの電力を
# モバイル端末に内蔵されたバッテリーで
# まかなうことはほぼ不可能です
# チャットGPTをはじめ
# データセンター上で稼働するタイプの
# AIの勝者はNVIDIAでほぼ間違いありません
# しかし端末上で稼働するタイプの
# AIの勝者はこの企業ではないでしょうか
# NVIDIAよりもこの企業に投資すべき
# 2つ目の理由
# それはNVIDIAよりもこの企業は
# 割安に評価されているということです
# 企業の株価を割安か割高かを判断する指標で
# 株価収益率、PERというものがあります
# PERが低ければ低いほど
# 実際の価値よりも低く評価されていると言えます
# PERが低い企業に投資をすれば
# その株が正当な評価をされるだけで
# 高いリターンを狙うことができます
# NVIDIAのPERは34.6
# この企業のPERは13.5です
# NVIDIAよりも2.56倍も
# 割安に評価されているということです
# つまりこの企業は正当な評価がされるだけで
# NVIDIAよりも高い株価成長が
# 狙えるということです
# また米国株の平均的PERは23.2
# この企業のPER13.5というのは
# 平均的な米国株から見ても
# 割安な水準にあると言えるでしょう
# NVIDIAは直近の決算でも
# ウォール外の予測を上回る
# 高要石を発表しました
# 一般投資家はNVIDIAの業績に夢中で
# この企業の価値に気がついていない可能性があります
# 今のうちにこの企業に投資しておけば
# 未来のスマートフォンが普及した時に
# 爆発的に高いリターンを狙うことができるかもしれません
# 一般投資家がこの企業の価値に気がつく前に
# 投資をしてください
# そしてNVIDIAよりもこの企業に投資すべき
# それはNVIDIAよりも高い株価成長を狙える
# 投資先でありながら
# 高い配当を受け取ることができるということです
# 一つ目と二つ目の理由から
# この企業はNVIDIAよりも高い株価成長が
# 狙える投資先であることは
# お分かりいただけたかと思いますが
# この企業はNVIDIAよりも高い株価成長を
# 狙えるだけではなく
# 高い配当収入も受け取ることができます
# この企業の配当リマーリはNVIDIAの34倍
# 同じ金額を投資するのであれば
# NVIDIAよりも圧倒的に高い配当を
# 受け取ることができます
# つまりまとめるとこの企業に投資することで
# NVIDIAよりも高い株価成長を狙える上に
# 高い配当を受け取ることができるということです
# ここまでスマホを超えると称されるモバイル端末
# AIスマホを紹介してきましたが
# いかがだったでしょうか
# こんなものがiPhoneを超えるなんてあり得ない
# こんなものが社会に普及するわけがない
# もしあなたがこのように感じているのであれば
# 逆にそれはチャンスです
# 周りの人もあなたと同じように
# 懐疑的に思っている可能性が高いからです
# 新しいテクノロジーが登場するとき
# 人は皆そのテクノロジーに対して懐疑的になります
# だからこそ新しいテクノロジーの可能性に
# 気がついた人にチャンスが巡ってきます
# 初代iPhoneが発表されたときも
# 同じように懐疑的な意見が見られました
# それでもiPhoneの可能性を信じた人のみが
# 莫大なリターンを得ることができました
# ぜひあなたもAIスマホの可能性を信じて
# この企業への投資を検討してください
# GPTシリコン市場のシェア率No.1の企業についての
# 詳細な分析をまとめた
# VICE RATINGSの公式レポート
# GPTシリコン新素材から作られる
# 半導体の照射銘柄を作成しました
# この公式レポートGPTシリコンでは
# 私たちがGPTシリコンと呼ぶ
# 半導体素材の正体
# そしてその市場で圧倒的なシェア率を誇る
# 企業の詳細な分析を紹介しています
# 未来のスマートフォンの登場という
# 投資チャンスで高いリターンを狙うために
# あなたが必要だと考えられる
# 全ての情報を盛り込んだので
# 安心して投資していただけると思います
# このレポートを作成するために
# 市場分析から銘柄選定まで行ったのが
# アメリカの投資格付け機関VICE RATINGS
# 1971年に創業されたVICE RATINGSは
# 50年以上にわたり独自の格付けシステムを駆使し
# 上昇前のハイテク銘柄を数億特定
# 世界中の投資家に海水賞を出してきました
# VICE RATINGSは2004年9月27日
# Appleに買いの格付けを発表
# そこからAppleの株価は28,016%上昇
# そこから3日後の2004年9月30日には
# Microsoftに買いの格付けを発表
# そこからMicrosoftの株価は1,201%上昇
# さらに3ヶ月後の2004年12月31日には
# Amazonに買いの格付けを発表
# そこからAmazonの株価は7,637%上昇
# そこから約1年後の2005年10月3日には
# NVIDIAに買いの格付けを発表
# そこからNVIDIAの株価は3,2420%上昇
# このようにテクノロジー投資に強みを持つ
# VICE RATINGSは今では超有名企業となった
# ハイテク銘柄を早い段階で買い推奨
# 世界中の投資家が資産を増やすお手伝いをしてきました
# アメリカの大手金融メディア
# Wall Street JournalはNo.1の格付け会社と報道
# 100年以上の歴史を持つ金融メディアのバロンズからは
# 適切なリスクで安定したリターンを求める投資家にとって
# VICE RATINGSの格付けは価値のあるものになると報道されました
# そんなVICE RATINGSがNVIDIAよりも高いリターンが狙えると分析した
# 半導体名柄の情報が
# VICE RATINGS公式レポートGPT Siliconには詰まっています
# 公式レポートGPT Siliconは1800円
# 税込み価格1980円で販売しています
# しかし一般投資家はNVIDIAに夢中で
# この企業の価値に気がついていない今
# できるだけ多くの方に投資してもらい
# 高いリターンを狙ってほしいと考えています
# なのでこの動画を見てご購入を決断してくれた方に
# 通常価格1800円から50%オフの900円
# 税込み価格990円にてご提供いたします
# 公式レポートGPT Siliconで紹介している名柄は
# NVIDIAですら市場に参入できていない
# しかしAIがスマホに搭載されるという
# 生成AIの次のフェーズで重要な役割を果たす
# GPT Silicon市場でトップシェアの企業
# もしかしたら次のNVIDIAとなる可能性を秘めた企業です
# 生成AI向けの半導体市場でトップシェアを誇るNVIDIAは
# 生成AI部分が到来した2023年から2年間で908%上昇
# もし10万円投資していれば今頃100万円以上になっていました
# レポート価格は990円たったランチ1回分程度の価格で
# これほどまで高いリターンを狙うことができるということです
# ここまでの話を聞いてもしかしたらあなたは
# そんなすごい名柄の情報を
# なぜそれほど安い値段で売っているのかと思われたかもしれません
# その理由は2つあります
# 1つは先ほどお伝えした通り
# できるだけ多くの方に高いリターンを狙って欲しいというものです
# 現在この企業の株価は18ドル
# 日本円で2700円程度で購入することができてしまいます
# 2024年9月9日にアップルはAI搭載のiPhoneを発売しましたが
# AI搭載のスマホが世の中に多く登場すれば
# 一般の投資家もこの企業の価値に気がつき
# 投資する可能性があります
# そうなれば1株18ドル程度の安値で
# 買うことが難しくなるかもしれません
# 1株18ドルNVIDIAの2.56倍も割安に評価されている今のうちに
# 多くの方に投資して欲しいと考えて
# 50%offの税込み価格990円で提供しています
# そしてもう一つの理由は
# 一人でも多くの日本人に
# このレポートを受け取って欲しいからというものです
# 投資の成功には良質な情報が欠かせません
# その中でも私たちが特に貴重だと考えているのは
# 中立的な情報です
# 実際に私たちはどこの証券会社にも属していませんし
# 株や投資信託などを販売することで
# 手数量を得るビジネスモデルでもありません
# ですからあなたがこのレポートを読んで
# 株を買ったとしても私たちには1円も入りません
# 私たちの収入源はコンテンツの高読量です
# そのため私たちの事業は
# そのコンテンツの密度や精度をいかに高め
# 個人投資家にとって
# いかに役立つ情報を提供できるかにかかっています
# だからこそ私たちは
# スタンダード&プアーズやムーディーズなどの
# 誰もが知る有名な格付け機関ではなく
# 高い特立性を持った
# Yスレッティングスと事業連携しています
# 通常の格付け機関は格付け対象の企業から
# 手数料を受け取って格付けを行います
# つまり格付け機関にとって
# 格付け対象の企業は顧客でもあります
# そのため顧客側の企業は格付け機関に対し
# 格付けのやり直しを依頼することもできます
# ですがYスレッティングスは格付け対象の企業や
# その他のスポンサーから手数料を受け取りません
# Yスレッティングスの顧客は格付けを利用して
# 投資を行う個人投資家です
# 当然Yスレッティングスの格付けに対し
# 格付け対象の企業がやり直し
# 評価の修正を依頼することはできません
# 格付け対象から完全に独立した立場から
# 格付け評価を行うYスレッティングスと
# 事業連携することで
# どこの企業にも損卓していない中立的な情報
# 個人投資家にとって本当に有益な情報を
# 届けることができます
# Yスレッティングスの権威ある投資専門家が
# 分析した本物の情報
# 米国現地で行われるリサーチならではの
# 日本では手に入らないリアルな情報
# このような情報を届き続けることで
# 初めて私たちのビジネスは
# 存続することができるのです
# そしてYスレッティングス公式レポートにも
# そんな情報が詰まっています
# だからこそこのレポートを一人でも
# 多くの日本人に受け取ってほしい
# そして私たちのことを信頼してくれる
# 投資家の方が一人でも増えるなら
# それほど嬉しいことはないと思っています
# そんな思いから通常価格1980円のレポートを
# 50%オフの税込み価格990円にて
# ご提供しています
# ぜひこの機会にレポートを
# 手に取っていただきたいと考えています
# さらにこれだけではありません
# このページからレポートを購入してくれた方に
# Yスレッティングスの創業者の
# オンライン講座を合わせてお届けします
# AIブーム3年目の2025年
# 今年もAIブームは続くのか
# 今からNVIDIAに投資してもいいのか
# そんな悩みを持つ方もいらっしゃるのではないでしょうか
# Yスレッティングス創業者マーティン・ワイス氏は
# そんな悩みを解決するために
# オンライン講座を作成してくれました
# 解決するといっても
# AIブームはまだ続くや
# もうAIブームは終わりだ
# なんて予測するわけではありません
# このAI名柄ならずっと伸び続けるなんて
# 有料なAI名柄を紹介するわけでもありません
# オンライン講座では
# AIブームが続くかどうかに限らず
# 配当衆議を受け取りながら
# 10年20年と長期にわたって
# 安定した資産成長を狙える
# そしてAIのような新しいテクノロジーの
# 普及によって
# 短期間で高いリターンを狙うことができる
# 一度の投資で3度も多いし
# そして一度学習すれば
# 何度でも使える投資戦略を紹介します
# もうあなたはAIブームが続くかどうかや
# NVIDIAの株価の下落について
# 心配する必要も不安になる必要もありません
# なぜなら
# ワイス氏が教える投資戦略をマスターすれば
# 配当を受け取りながら
# 長期的な資産成長のみならず
# AIのような新しいテクノロジーの
# 普及によって
# 短期間で高いリターンを狙うことも
# できるようになるからです
# レポートGPTシリコンで紹介している
# 半導体名柄は
# AIスマホに搭載される
# GPTシリコン市場でトップシェアの企業です
# この企業に投資をすれば
# AIスマホの普及というテクノロジートレンドに乗って
# 高いリターンが狙えると考えています
# ですが
# 今日ワイスレイティングスジャパンの情報を受け取って
# 投資を始めるとご決断された方には
# AIスマホの普及というトレンドだけではなく
# 今後数十年にわたって
# 長期的な資産傾線が狙っていける
# 投資戦略を身につけていただきたいと考えています
# そのため公式レポートGPTシリコンと一緒に
# ワイス市のオンライン講座も合わせてお届けしています
# レポートのご購入後にお届けするメールから
# ワイス市のオンライン講座を見ることができます
# 公式レポートGPTシリコンで紹介されている
# 名柄情報に加えて
# ワイスレイティング創業者の
# ワイス市のオンライン講座も手に入れてください
# そして最後にもう一つ
# あなたにお伝えしたいことがあります
# それは公式レポートGPTシリコンには
# 1ヶ月間の返金保障がついているということです
# あなたは1ヶ月の間
# 実際にレポートを読み
# GPTシリコンの正体
# そしてその市場のナンバーワン企業とは
# どんな企業なのか
# ワイス市が教える投資戦略は
# 一体何なのかを確認することができます
# 実際にご覧になった後に
# 聞いていた話と全然違った
# これでは高いリターンは期待できないと思うならば
# 1ヶ月以内にカスタマーサポートまで
# ご連絡をいただければ
# 全額ご返金させていただきます
# このページの動画下に
# 申し込みフォームのリンクがありますので
# そこをクリックして
# 申し込み手続きにお済みください

# %%
display(text)
# Out:
# '世界は産業革命に匹敵する変革の時を迎えています 世界最大の資産運用会社ブラックロック ai の進歩は我々を最も驚かせた世界最大級の投資銀行ゴールドマンサックス ai の次の波はロボットだ n ビディア ceo ジェンスンファン これまでの人類の歴史上最大の製品になる可能性がある テスラ ceo イーロンマスク 今ご紹介した言葉はいずれも ai ブームの次のトレンドについて語られたものです 資産運用会社ブラックロックのアナリストは今の ai ブームは産業革命に匹敵する変革であると語り ai の次に高い成長が狙える分野はロボットだと 語りました ゴールドマンサックスのアナリストは ai の急速な進化によりロボット市場の成長率の予測を情報修正 以前の予測である60億ドルから6倍以上の380億ドルに変更しました ai の進歩は我々を最も驚かせたとアナリストは語っています 現在の生成 ai の波を経緯する nvidia の ceo ジェンスファンはロボットを刺しながらこれが ai の次の波だと発言 ai が搭載された自立マシンやロボットが普及する未来の可能性について語りました イーロンマスク氏が率いるテスラは二足歩行する人型ロボット オプティマスの開発を発表 テスラボットとも呼ばれるこの人型ロボットは掃除や洗濯料理の補助など日常的な家事の サポート高齢者や障害者の生活支援子供の教育支援など幅広い活用が期待されています イーロンマスク氏はテスラにとっていずれ自動車事業よりも重要になる可能性がある 2025年に自社工場で1000台以上を稼働させる これまでの人類の歴史上最大の製品になる可能性があると語っています その中にはこのロボットがテスラの自家総額を40倍以上に押し上げるといった驚きの 主張もあります ここまでの話を聞いたあなたはロボットなんて実現しない 実現したとしても遠い未来だと思われるかもしれません 確かに人型ロボットが私たちの生活に普及するのは遥か先の未来 もしくは全く実現しない可能性もあります ですがAIが搭載された機械は実はもうすでに私たちの生活に浸透しつつあります それはAIスマホです 現在生成AIが搭載されたスマートフォンAIスマホが世の中に普及しつつあります 例えばアップルは独自の生成AIアップルインテリジェンスを搭載したAIスマホを発売 中でも今年2月に発売されたiphone6 teはアップルインテリジェンスの活用により最強の AIスマホと呼ばれています 人気シリーズギャラクシーを発売するサムソンも生成AIを搭載したスマホを開発 まるで秘書がスマホの中にいるようだや仕事を任せられるといったほどの 画期的な性能を誇っていると言われています 生成AIジェミニを提供するグーグルも生成AIを搭載したグーグルピクセルを発売 AIスマホを開発するのは既存のスマホメーカーだけではありません チャットGPTを開発したオープンAIもAI界のiPhoneを目指してAIスマホの開発を発表 この計画にはiPhone、iMac、Apple Watchなどのアップルの主要な製品のデザインを多数手掛けた 元アップルの伝説的なデザイナージョナサン・アイブが参画しています 彼は2019年にアップルを退社しましたがそれまでアップルの最高デザイン責任者を務めており 初代iPhoneも彼の作品です オープンAIとジョナサン・アイブ氏が手掛けるAI界のiPhone どんなスマホになるのかまだ詳しいことは明かされていませんが スマホにAIが搭載されることは間違いないでしょう AIスマホの登場は私たちの生活を大きく変えるイノベーションになるかもしれません アップルが初代iPhoneを発表した2007年1月9日 その日アップルのCEOスティーブ・ジョブズは本日アップルが電話を再発明すると高らかに宣言し 初代iPhoneを発表しました 宣言通りiPhoneは電話を再発明したと言っても過言ではありません それまで日本では柄系と呼ばれるモバイル端末が主流でしたが iPhoneをはじめスマートフォンが使われるようになりました 2010年の携帯電話所有者のスマホの比率は4.4% それが10年で88.9%まで上昇しました この期間アップルの株価は1,028%上昇 これは100万円投資していれば資産を1,128万円までに増やすことができていたということです そしてAIスマホの普及が期待される2025年 AIスマホを提供し電話を再発明する企業の中から高い株価成長を果たすものが出てくるかもしれません さらに今回の電話の再発明はアップルの時よりも高いリターンが狙える可能性があります なぜならアップルが初代iPhoneを発売した2007年と現在では世界人口が圧倒的に違うからです 2007年から2025年現在までの間で世界人口は14.6億人も増加したと言われています それだけ多くの人がAIスマホを持つようになれば当然AIスマホ市場を支配する企業はアップルよりも高い株価成長を果たす可能性があります AIスマホ市場を支配する端末をスマホの先書きになったiPhoneに掛け合わしGPTフォンと私たちは呼んでいます GPTフォンを開発しAIスマホ市場を支配する企業にいち早く投資をすることができれば 初代iPhoneを発売した時のアップル以上に高いリターンを狙うことができるかもしれません GPTフォンを発売しアップルの次に電話を再発明するのはどの企業になるのでしょうか 元アップルの伝説的なデザイナーと手を組んだオープンAIでしょうか スマホ市場の勝者アップルが今回も電話を再発明することになるのでしょうか それとも全く別の企業が革命を起こすことになるのでしょうか 実はもうすでにスマホを超えたと称されるAIデバイスを開発した企業が存在します この動画ではその企業についても紹介しています さらにどの企業がGPTフォンを発売することになったとしても 利益が狙える名柄も名前まで明かして紹介しているので この動画を見るだけでNVIDIA CEO Jensenファンが語るAIの次の波に乗って 高いリターンを狙うことができます このページにたどり着いた今動画を見てぜひ投資を検討してみてください チャプター1 未来のスマホGPTフォンにはアプリがない いずれスマートフォンのアプリは消える なぜならAIがアプリにとって変わるからだ そう主張するのは世界的な通信事業者ドイツテレコム社のCEOです ドイツテレコム社が発売したティーフォンにはアプリはありません AIがアプリの役割を果たします ユーザーはAIにしたいことを伝えるだけでいいのです 旅行に行きたい時 航空券を予約したいと端末に伝えるだけで ホーム画面に候補となるフライトのリストが表示されます あとは好きなモバイル決済システムで即座に支払いまで完了できます 他のアプリやサービスに切り替える必要は一切ありません ティーフォンを開発したドイツテレコム社のCEOは次のように語っています 今のアプリシステムはユーザーが考えなければならないことが多い しかし今後はAIにしたいことを伝えるだけで AIが必要なフローを組み立ててくれる さらにアプリのないスマホを開発したのは彼だけではありません 他にもアプリが存在しないモバイル端末を発売したスタートアップ企業が存在します あなたは毎年1月にラスベガスで開催される カスタマーエレクトロニクスショー通称SESをご存知でしょうか? このイベントには毎年世界中から数千社以上のテクノロジー企業が集まり 最先端のデジタル製品が披露されます 昨年開催されたSES2024でも世界中から4千を超える企業が出展 13万人近くの参加者が訪れました 空飛ぶ車や中身が透けて見える透明なテレビなど 革新的な商品が会場に並ぶ中 スマホを超えると称されるモバイル端末が紹介されました そのモバイル端末はラビット社が開発したラビットR1です 日本のメディアもニュースに取り上げているので あなたもご存知あるかもしれません スマホを超えると言われていますが その見た目はスマホとは全く異なるものです ご覧の通りこのモバイル端末にはスクロールホイールがついているだけです 画面はタッチスクリーンであるものの スマホの半分程度のサイズしかありませんし アプリも存在しません そんなモバイル端末をどうやって操作するのか 疑問に思われたかもしれません ラビットR1は音声で操作が可能です 何かのタスクをこなすためには適切なアプリを探し出し 画面を何度もタップする必要はありません ユーザーはラビットR1の側面についたボタンを押しながら やりたいことを友達にお願いするように伝えるだけでいいのです ラビットR1は数秒でユーザーのリクエストを解析し 画面にうんちんなどの詳細を示すカードを表示 廃車を依頼します ラビットR1ができることは滝にわたります レストランの予約や航空券の予約 Spotifyのプレイリストへの曲の追加 様々なことがアプリなしで音声操作が可能です iPhoneのSiriやGoogleアシスタントとは異なり ラビットR1には高性能なAIが搭載されており ユーザーの行動を学習し ユーザーが望む行動を正確に実行することができます それにより従来のスマートフォンには 不可能な音声操作が可能となっているということです ラビットR1の販売価格は199ドル 約2万9000円で販売が始まりましたが たった1日で初回販売台数の1万台は売り切れとなりました ラビットR1を開発したラビット社は 発売日に500台の販 ...
